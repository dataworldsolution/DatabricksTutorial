# %% [markdown]
# ![image_1780239358709.png](./image_1780239358709.png "image_1780239358709.png")

# %% [markdown]
# ![image_1780239433693.png](./image_1780239433693.png "image_1780239433693.png")

# %% [markdown]
# ![image_1780239541655.png](./image_1780239541655.png "image_1780239541655.png")

# %% [markdown]
# ## Step by Step Demo

# %%
from delta.tables import DeltaTable

# %%
data = [
    (101, "John", 5000),
    (102, "David", 6000),
    (103, "Smith", 7000)
]

df = spark.createDataFrame(data, ["employee_id", "employee_name", "salary"])
df.show()
# Out:
# +-----------+-------------+------+
# |employee_id|employee_name|salary|
# +-----------+-------------+------+
# |        101|         John|  5000|
# |        102|        David|  6000|
# |        103|        Smith|  7000|
# +-----------+-------------+------+

# %%
df.write.format("delta").save("/Volumes/demoyt/default/volume_demo/employee_delta")

# %% [markdown]
# ### Load Delta Table Using Delta Table API

# %%
dt = DeltaTable.forPath(spark, "/Volumes/demoyt/default/volume_demo/employee_delta")

# %% [markdown]
# ### - Update Single Records Example

# %%
dt.update(
    condition= "employee_id = 102",
    set = {"salary":"8000"}
)
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.read.format("delta").load("/Volumes/demoyt/default/volume_demo/employee_delta").show()
# Out:
# +-----------+-------------+------+
# |employee_id|employee_name|salary|
# +-----------+-------------+------+
# |        101|  John Miller|  6500|
# |        102|        David|  8800|
# |        103|        Smith|  7700|
# +-----------+-------------+------+

# %% [markdown]
# ### Update MUltiple Records (NO Condition)

# %%
dt.update(
    set ={"salary":"salary*1.10"}

)
# Out:
# DataFrame[num_affected_rows: bigint]

# %% [markdown]
# ## Update Multiple Columns

# %%
dt.update(
    condition = "employee_id = 101",
    set = {
        "salary":"6500",
        "employee_name":"'John Miller'"
    }
)
# Out:
# DataFrame[num_affected_rows: bigint]
