# %% [markdown]
# ## DataFrame Writer API is Limited

# %%
data = [
    (1, "C101", "Laptop", 50000, "2024-01-01", None),
    (2, "C102", "Mobile", 20000, "2024-01-02", "NEWYEAR"),
    (3, "C103", "Tablet", None, "2024-01-03", None),  # missing price
    (4, "C101", "Laptop", 50000, "2024-01-01", None), # duplicate
    (5, "C104", "Headphones", 2000, "2024-01-04", None),
    (6, "C105", "Camera", 30000, "2024-01-05", "SALE10")
]

columns = ["order_id", "customer_id", "product", "amount", "order_date", "coupon"]

df= spark.createDataFrame(data, columns)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>product</th><th>amount</th><th>order_date</th><th>coupon</th></tr></thead><tbody><tr><td>1</td><td>C101</td><td>Laptop</td><td>50000</td><td>2024-01-01</td><td>null</td></tr><tr><td>2</td><td>C102</td><td>Mobile</td><td>20000</td><td>2024-01-02</td><td>NEWYEAR</td></tr><tr><td>3</td><td>C103</td><td>Tablet</td><td>null</td><td>2024-01-03</td><td>null</td></tr><tr><td>4</td><td>C101</td><td>Laptop</td><td>50000</td><td>2024-01-01</td><td>null</td></tr><tr><td>5</td><td>C104</td><td>Headphones</td><td>2000</td><td>2024-01-04</td><td>null</td></tr><tr><td>6</td><td>C105</td><td>Camera</td><td>30000</td><td>2024-01-05</td><td>SALE10</td></tr></tbody></table></div>

# %%
df.write.format("delta").mode("overwrite").save("/Volumes/demoyt/default/volume_demo/order")

# %%
df.write.format("delta").mode("overwrite").saveAsTable("DemoYT.default.demo_order")

# %%
df.write.format("delta").mode("append").saveAsTable("DemoYT.default.demo_order")

# %%
# %sql
select * from demoyt.default.demo_order
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>product</th><th>amount</th><th>order_date</th><th>coupon</th></tr></thead><tbody><tr><td>1</td><td>C101</td><td>Laptop</td><td>50000</td><td>2024-01-01</td><td>null</td></tr><tr><td>2</td><td>C102</td><td>Mobile</td><td>20000</td><td>2024-01-02</td><td>NEWYEAR</td></tr><tr><td>3</td><td>C103</td><td>Tablet</td><td>null</td><td>2024-01-03</td><td>null</td></tr><tr><td>4</td><td>C101</td><td>Laptop</td><td>50000</td><td>2024-01-01</td><td>null</td></tr><tr><td>5</td><td>C104</td><td>Headphones</td><td>2000</td><td>2024-01-04</td><td>null</td></tr><tr><td>6</td><td>C105</td><td>Camera</td><td>30000</td><td>2024-01-05</td><td>SALE10</td></tr></tbody></table></div>

# %% [markdown]
# ### Creating a Delta Table Instance

# %%
from delta.tables import DeltaTable

# %% [markdown]
# ## forName

# %%
dt = DeltaTable.forName(spark,"demoyt.default.demo_order")

# %%
type(dt)
# Out:
# delta.connect.tables.DeltaTable

# %% [markdown]
# ## forPath

# %%
dt = DeltaTable.forPath(spark,"/Volumes/demoyt/default/volume_demo/order")

# %%
type(dt)
# Out:
# delta.connect.tables.DeltaTable
